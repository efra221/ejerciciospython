# %%
import pandas as pd

# %%
import pandas as pd

#crear un dataframe
df = pd.read_csv("poblacion.csv")
print(df)
# Out:
#     Date     ABW       AFG       AGO      ALB    AND        ARB      ARE  \
# 0   1960   54608   8622466   5357195  1608800   9443   93359407   133426
# 1   1961   55811   8790140   5441333  1659800  10216   95760348   140984
# 2   1962   56682   8969047   5521400  1711319  11014   98268683   148877
# 3   1963   57475   9157465   5599827  1762621  11839  100892507   157006
# 4   1964   58178   9355514   5673199  1814135  12690  103618568   165305
# ..   ...     ...       ...       ...      ...    ...        ...      ...
# 59  2019  106442  37769499  32353588  2854191  76343  441467739  9211657
# 60  2020  106585  38972230  33428486  2837849  77700  449228296  9287289
# 61  2021  106537  40099462  34503774  2811666  79034  456520777  9365145
# 62  2022  106445  41128771  35588987  2777689  79824  464684914  9441129
# 63  2023  106277  42239854  36684202  2745972  80088  473272080  9516871
#
#          ARG      ARM  ...     VIR       VNM     VUT         WLD     WSM  \
# ...

# %%
df.head(2)       # Primeras 5 filas
# Out:
#    Date    ABW      AFG      AGO      ALB    AND       ARB     ARE       ARG  \
# 0  1960  54608  8622466  5357195  1608800   9443  93359407  133426  20349744
# 1  1961  55811  8790140  5441333  1659800  10216  95760348  140984  20680653
#
#        ARM  ...    VIR       VNM    VUT         WLD     WSM      XKX      YEM  \
# 0  1904148  ...  32500  32718461  64608  3031517384  113335   990150  5542459
# 1  1971530  ...  34300  33621982  66462  3072470012  116820  1014211  5646668
#
#         ZAF      ZMB      ZWE
# 0  16520441  3119430  3806310
# 1  16989464  3219451  3925952
#
# [2 rows x 264 columns]

# %%
df.tail(2)       # Últimas 5 filas
# Out:
#     Date     ABW       AFG       AGO      ALB    AND        ARB      ARE  \
# 62  2022  106445  41128771  35588987  2777689  79824  464684914  9441129
# 63  2023  106277  42239854  36684202  2745972  80088  473272080  9516871
#
#          ARG      ARM  ...     VIR       VNM     VUT         WLD     WSM  \
# 62  46234830  2780469  ...  105413  98186856  326740  7951595433  222382
# 63  46654581  2777970  ...  104917  98858950  334506  8024997028  225681
#
#         XKX       YEM       ZAF       ZMB       ZWE
# 62  1768086  33696614  59893885  20017675  16320537
# 63  1756374  34449825  60414495  20569737  16665409
#
# [2 rows x 264 columns]

# %%
df.info()       # Información general
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Columns: 264 entries, Date to ZWE
# dtypes: float64(1), int64(263)
# memory usage: 132.1 KB

# %%
df.describe()
# Out:
#               Date            ABW           AFG           AGO           ALB  \
# count    64.000000      64.000000  6.400000e+01  6.400000e+01  6.400000e+01
# mean   1991.500000   77906.500000  1.878244e+07  1.518896e+07  2.713609e+06
# std      18.618987   18820.577039  1.021302e+07  9.225153e+06  4.651967e+05
# min    1960.000000   54608.000000  8.622466e+06  5.357195e+06  1.608800e+06
# 25%    1975.750000   61073.500000  1.050779e+07  7.208263e+06  2.445102e+06
# 50%    1991.500000   69028.000000  1.296262e+07  1.243060e+07  2.878402e+06
# 75%    2007.250000   97089.250000  2.603428e+07  2.110514e+07  3.042464e+06
# max    2023.000000  106585.000000  4.223985e+07  3.668420e+07  3.286542e+06
#
#                 AND           ARB           ARE           ARG           ARM  \
# count     64.000000  6.400000e+01  6.400000e+01  6.400000e+01  6.400000e+01
# mean   50480.640625  2.496709e+08  3.434974e+06  3.320280e+07  2.927306e+06
# ...

# %%
df["COL"]
# Out:
# 0     15687688
# 1     16182414
# 2     16691282
# 3     17210956
# 4     17739754
#         ...
# 59    50187406
# 60    50930662
# 61    51516562
# 62    51874024
# 63    52085168
# Name: COL, Length: 64, dtype: int64

# %%
df[["Date","COL", "CHN"]]
# Out:
#     Date       COL         CHN
# 0   1960  15687688   667070000
# 1   1961  16182414   660330000
# 2   1962  16691282   665770000
# 3   1963  17210956   682335000
# 4   1964  17739754   698355000
# ..   ...       ...         ...
# 59  2019  50187406  1407745000
# 60  2020  50930662  1411100000
# 61  2021  51516562  1412360000
# 62  2022  51874024  1412175000
# 63  2023  52085168  1410710000
#
# [64 rows x 3 columns]

# %%
df[df["Date"] > 2020]
# Out:
#     Date     ABW       AFG       AGO      ALB    AND        ARB      ARE  \
# 61  2021  106537  40099462  34503774  2811666  79034  456520777  9365145
# 62  2022  106445  41128771  35588987  2777689  79824  464684914  9441129
# 63  2023  106277  42239854  36684202  2745972  80088  473272080  9516871
#
#          ARG      ARM  ...     VIR       VNM     VUT         WLD     WSM  \
# 61  45808747  2790974  ...  105870  97468029  319137  7888963821  218764
# 62  46234830  2780469  ...  105413  98186856  326740  7951595433  222382
# 63  46654581  2777970  ...  104917  98858950  334506  8024997028  225681
#
#         XKX       YEM       ZAF       ZMB       ZWE
# 61  1786038  32981641  59392255  19473125  15993524
# 62  1768086  33696614  59893885  20017675  16320537
# 63  1756374  34449825  60414495  20569737  16665409
#
# [3 rows x 264 columns]

# %%
#Agregar una nueva columna
df["Nuevopais"] = df["COL"] + 1000000
df.head()
# Out:
#    Date    ABW      AFG      AGO      ALB    AND        ARB     ARE       ARG  \
# 0  1960  54608  8622466  5357195  1608800   9443   93359407  133426  20349744
# 1  1961  55811  8790140  5441333  1659800  10216   95760348  140984  20680653
# 2  1962  56682  8969047  5521400  1711319  11014   98268683  148877  21020359
# 3  1963  57475  9157465  5599827  1762621  11839  100892507  157006  21364017
# 4  1964  58178  9355514  5673199  1814135  12690  103618568  165305  21708487
#
#        ARM  ...       VNM    VUT         WLD     WSM      XKX      YEM  \
# 0  1904148  ...  32718461  64608  3031517384  113335   990150  5542459
# 1  1971530  ...  33621982  66462  3072470012  116820  1014211  5646668
# 2  2039346  ...  34533889  68391  3126894230  120163  1038618  5753386
# 3  2106142  ...  35526727  70400  3193470069  123416  1063175  5860197
# 4  2171029  ...  36509166  72493  3260479625  126582  1087700  5973803
#
#         ZAF      ZMB      ZWE  Nuevopais
# ...

# %%
# Eliminar una columna
df = df.drop("Nuevopais", axis=1)
df.head()
# Out:
#    Date    ABW      AFG      AGO      ALB    AND        ARB     ARE       ARG  \
# 0  1960  54608  8622466  5357195  1608800   9443   93359407  133426  20349744
# 1  1961  55811  8790140  5441333  1659800  10216   95760348  140984  20680653
# 2  1962  56682  8969047  5521400  1711319  11014   98268683  148877  21020359
# 3  1963  57475  9157465  5599827  1762621  11839  100892507  157006  21364017
# 4  1964  58178  9355514  5673199  1814135  12690  103618568  165305  21708487
#
#        ARM  ...    VIR       VNM    VUT         WLD     WSM      XKX      YEM  \
# 0  1904148  ...  32500  32718461  64608  3031517384  113335   990150  5542459
# 1  1971530  ...  34300  33621982  66462  3072470012  116820  1014211  5646668
# 2  2039346  ...  35000  34533889  68391  3126894230  120163  1038618  5753386
# 3  2106142  ...  39800  35526727  70400  3193470069  123416  1063175  5860197
# 4  2171029  ...  40800  36509166  72493  3260479625  126582  1087700  5973803
#
# ...
